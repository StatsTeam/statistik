# %% [markdown]
# # Aufgaben zu: Darstellung qalitativer Daten
#
# ## 1. Aufgabe
#
# Nach der Wahl am 24.09.2017 ergab sich die folgende Sitzverteilung im 19. Deutschen Bundestag:
#
# | Merkmalsausprägung | Absolute Häufigkeit |
# | :----------------: | :-----------------: |
# |       Union        |         246         |
# |        SPD         |         153         |
# |        AfD         |         94          |
# |        FDP         |         80          |
# |       Linke        |         69          |
# |       Grüne        |         67          |
#
# Ergänzen Sie die Tabelle um die Spalte Relative Häufigkeit und Prozent.
# Erstellen Sie außerdem noch ein Balkendiagramm!
#
# ### Lösung
#
# | Merkmalsausprägung | Absolute Häufigkeit | Relative Häufigkeit | Prozent  |
# | :----------------: | :-----------------: | ------------------- | -------- |
# |       Union        |         246         | $0,347$             | $34,7\%$ |
# |        SPD         |         153         | $0,216$             | $21,5\%$ |
# |        AfD         |         94          | $0,133$             | $13,3\%$ |
# |        FDP         |         80          | $0,113$             | $11,3\%$ |
# |       Linke        |         69          | $0,097$             | $9,7\%$  |
# |       Grüne        |         67          | $0,094$             | $9,4\%$  |
# |       Summen       |         709         | 1                   | $100\%$  |
#
# <br>
# <img src="../img/balkendiagramm_horizontal_03.png" alt="Stabdiagramm" width="500">
#
# ## 2. Aufgabe
#
# In einer Packung Gummibärchen befinden sich 30 weiße, 36 gelbe, 32 grüne, 30 hellrote, 40 orangene und 32 dunkelrote Gummibärchen.
#
# 1. Berechnen Sie für jede Farbe die relative Häufigkeit.<br>
#    Bilden Sie die Summe aller absoluten und relativen Häufigkeiten. Welche Eigenschaften der absoluten und der relativen Häufigkeiten zeigen sich dabei?
#
# 2. Stellen Sie die Daten in einer geeigneten Form grafisch dar.
#
# ### Lösung
#
# 1. Summe aller Merkmalsausprägungen: $n=200$
#
#    | Merkmalsausprägung | Absolute Häufigkeit | Relative Häufigkeit | Prozent  |
#    | :----------------: | :-----------------: | ------------------- | -------- |
#    |        Weiß        |         30          | $0,15$              | $15\%$ |
#    |        Gelb        |         36          | $0,18$              | $18\%$ |
#    |        Grün        |         32          | $0,16$              | $16\%$ |
#    |      Hellrot       |         30          | $0,15$              | $15\%$ |
#    |       Orange       |         40          | $0,2$               | $20\%$  |
#    |     Dunkelrot      |         32          | $0,16$              | $16\%$  |
#    |       Summe        |         200         | 1                   | $100\%$  |
#
# <br>
# 2. Horizontales Balkendiagramm:
# <br>
# <br>
# <img src="../img/balkendiagramm_horizontal_04.png" alt="Stabdiagramm" width="500">
#
# ## 3. Aufgabe
#
# Bei einer Schulaufgabe ergab sich für die Noten folgende Verteilung:
#
#    | Note | Anzahl |
#    | :--: | :----: |
#    |  1   |   3    |
#    |  2   |   2    |
#    |  3   |   9    |
#    |  4   |   6    |
#    |  5   |   7    |
#    |  6   |   2    |
#
# Berechne die relativen Häufigkeiten!
#
# ### Lösung
#
# $n=20$
#
# $h_i=\frac{n_i}{n}$
#
#    | Note | Anzahl | Relative Häufigkeit |
#    | :--: | :----: | ------------------- |
#    |  1   |   3    | $0,103$             |
#    |  2   |   2    | $0,069%$            |
#    |  3   |   9    | $0,31$              |
#    |  4   |   6    | $0,207$             |
#    |  5   |   7    | $0,241$             |
#    |  6   |   2    | $0,069$             |
#
#
# ## 4. Aufgabe
#
# In einem Hörsaal sitzen 150 Studenten. 110 von ihnen sprechen nur Englisch, 20 nur Spanisch und 15 sprechen beide Sprachen.
#
# 1. Wie groß ist die relative Häufigkeit der Studenten, die mindestens eine der
#    beiden Sprachen sprechen?
#
# 2. Wie groß ist die relative Häufigkeit der Studenten, die keine der beiden
#    Sprachen sprechen?
#
# ### Lösung
#
# 1. Lösung:
#    $$\frac{110+20+15}{150}=\frac{145}{150}\approx0,9666\approx96,66\%$$
#
# 2. Lösung:
#    $$1-\frac{145}{150}\approx0,0333\approx3,33\%$$
#
# ## 5. Aufgabe
#
# Ein Viertel aller Schüler einer Klasse hat einen Hund, die Hälfte der Schüler hat eine Katze. Kein Schüler hat beide Haustiere. Ermittle den Anteil der Schüler, die keines dieser Haustiere haben.
#
# ### Lösung
#
# $\frac14+\frac12+x=1$
#
# $x=1-\frac14-\frac12=0,25=25\%$
